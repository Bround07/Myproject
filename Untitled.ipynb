# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
import cmapy
import pandas as pd

# %%
image = plt.imread('image.jpg')
image2 = cv2.imread('meme.jpg')

image.shape, image2.shape
# Out:
# ((626, 1200, 3), (360, 480, 3))

# %%
img_colorizedr = cv2.applyColorMap(image,  cmapy.cmap('PuBu'))
img_colorizedb = cv2.applyColorMap(image2, cmapy.cmap('winter'))

# Display
plt.imshow(img_colorizedr)
plt.show()
plt.imshow(img_colorizedb)
plt.show()

# %%
pd.Series(image.flatten()).plot(kind='hist',bins= 50,title= 'distribution of pixel')
plt.show()

# %%
fig,ax=plt.subplots(figsize=(10,10))
ax.imshow(image)
ax.axis('off')
plt.show()

# %%
fig,axs= plt.subplots(1,3, figsize=(15,15))
axs[0].imshow(image[:,:,0],cmap='Reds')
axs[1].imshow(image[:,:,1],cmap='Greens')
axs[2].imshow(image[:,:,2],cmap='Blues')
axs[0].axis('off')
axs[1].axis('off')
axs[2].axis('off')
axs[1].set_title('red')
axs[1].set_title('green')
axs[1].set_title('blue')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig,axs= plt.subplots(1,2, figsize=(10,5))
axs[0].imshow(image2)
axs[1].imshow(image)
axs[0].axis('off')
axs[1].axis('off')
axs[0].set_title('cv')
axs[1].set_title('matplolib')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
img_cv2_rgb = cv2.cvtColor(image2,cv2.COLOR_BGR2RGB)
fig, ax= plt.subplots()
ax.imshow(img_cv2_rgb)
ax.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
tamaño_imagen= cv2.resize(image,None,fx=0.25,fy=0.25)
fig, ax = plt.subplots(figsize=(8,8))
ax.imshow(tamaño_imagen)
ax.axis('off')
plt.show()

# %%
tamaño_imagen= cv2.resize(image,(100,200))
fig, ax = plt.subplots(figsize=(8,8))
ax.imshow(tamaño_imagen)
ax.axis('off')
plt.show()

# %%
tamaño_imagen= cv2.resize(image,(5000,5000),interpolation= cv2.INTER_CUBIC)
fig, ax = plt.subplots(figsize=(8,8))
ax.imshow(tamaño_imagen)
ax.axis('off')
plt.show()

# %%
kernel_sharpening = np.array([[-1,-1,-1],
                            [-1,9,-1],
                            [-1,-1,-1]])
sharpened= cv2.filter2D(image,-1,kernel_sharpening)
fig, ax = plt.subplots(figsize=(8,8))
ax.imshow(sharpened)
ax.axis('off')
plt.show()

# %%
kernel_3x3 = np.ones((3,3), np.float32)/9
blurred = cv2.filter2D(image,-1,kernel_3x3)
fig, ax = plt.subplots(figsize=(8,8))
ax.imshow(blurred)
ax.axis('off')
plt.show()
